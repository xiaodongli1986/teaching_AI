# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fontdict = {'family': 'Symbola',
#        'color':  'darkred',
        'weight': 'normal',
        'size': 26,
        }
fig, ax = subplots(figsize=(16,8))

ax.text(0.03, 0.75, 
        r'$y(\theta, x) = \theta^T x$'+'\n'+r'    $= \theta_n\ x_n + \theta_{n-1}\ x_{n-1}+...+\theta_1\  x_1 + \theta_0$', 
       fontdict=fontdict)
ax.text(0.03, 0.55, 
        r'$y(\theta, x) = g(\theta^T x)$', 
       fontdict=fontdict)

ax.text(0.03, 0.35, 
        r'$y=0.5,\ \theta^T x=0$', 
       fontdict=fontdict)

ax.text(0.03, 0.15, 
        r'$P(y=k,x)=\frac{\exp(\theta_k^T x)}{1+\sum_{k=1}^{K-1}\exp(\theta_k^T) x},\ k=1,2,...,K-1$', 
       fontdict=fontdict)
# Out:
# Text(0.03, 0.15, '$P(y=k,x)=\\frac{\\exp(\\theta_k^T x)}{1+\\sum_{k=1}^{K-1}\\exp(\\theta_k^T) x}$')

# %%
from sklearn import linear_model, model_selection, datasets, neighbors

# %%
data = datasets.load_digits()
X, y = data.data, data.target

# %%
for model, modelname in [
    [neighbors.KNeighborsClassifier(), 'knn'],
    [linear_model.LogisticRegressionCV(), 'logistic'],
    ]:
    print(modelname) 
    print(model_selection.cross_val_score(model, X, y, cv=5))
# Out:
# knn
# [0.9478022  0.9558011  0.96657382 0.98039216 0.96338028]
# logistic
# /home/xiaodongli/software/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /home/xiaodongli/software/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/xiaodongli/software/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ...

# %% [markdown]
# ### 练习题：测试目前学到的 Classifier 的 performance。
#
#     对以下几种模型：
#         n_neighbor = 3, 5, 10 的 knn
#         logestic 回归
#         单层 100 个 neuron 的 neural_network
#         单层 200 个 neuron 的 neural_network
#
#
#     测试它们以下数据集的表现：
#         iris
#         digits
#
#     请做到：
#
#         打印 model_selection.cross_val_score() 结果
#
#         把 validation 的结果作图，形象地演示（如，横坐表示不同的模型，纵坐标为 score，就像我ppt最后一页所示图）
